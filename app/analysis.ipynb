# %%
import pandas as pd
import numpy as np
from numpy import NaN
from itertools import chain
import json
from file_writer import VacancyDF

# %%
ac = pd.read_csv('results/1С-аналитик_vac.csv', sep=';', encoding='utf-8')

# %%
from file_writer import VacancyDF
i = VacancyDF('results/Аналитик данных_vac.csv', sep=';', encoding='utf-8')
i.drop_columns('job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency', axis=1, inplace=True)
i
# Out:
#            id             spec                                                                                                                                                                                                                                                                                                                                                                                                              skills
# 0    76279241  Аналитик данных                                                                                                                                                                                                                                                                                                 ms excel, бизнес-анализ, аналитические исследования, qlik sense, анализ данных, базы данных, аналитическое мышление
# 1    78521948  Аналитик данных                                                                                                                                                                                                                                                                                 sql, работа с базами данных, английский язык, сводные таблицы, внимательность, ответственность, работа с большим объемом информации
# 2    78345488  Аналитик данных                                                                                                                                                                                                                                                                                                                                                        анализ данных, tableau, статистический анализ, sql, power bi
# 3    79479573  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                       power bi, sql, powerbi, базы данных, ms excel
# 4    78054272  Аналитик данных                                                                                                                                                                                                                                                                                                                                                               opencv, аналитическое мышление, python, deep learning
# 5    77711309  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 6    79117415  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 7    78904415  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 8    77621497  Аналитик данных                                                                                                                                                                                                                                                                                                                     субд, arenadata, oracle, ms sql, sql, анализ данных, c++, bitbucket, python, team city, airflow
# 9    79027297  Аналитик данных                                                                                                                                                                                          ms excel, аналитические исследования, экономический анализ, продвинутый пользователь пк, готовность обучаться, креативность, анализ данных, работа с большим объемом информации, гибкость мышления, аналитическое мышление
# 10   77992314  Аналитик данных                                                                                                                                                                                                                                                                                                                                          sql, vba, data mining, android, прогнозирование, анализ бизнес показателей
# 11   79699299  Аналитик данных                                                                                                                                                                                                                                                                                                                                     ms excel, анализ бизнес показателей, аналитика продаж, power query, power pivot
# 12   78429464  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 13   79130507  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 14   79889720  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                     аналитик данных, экономическая безопасность, 1с
# 15   79578743  Аналитик данных                                                                                                                                                                                                                                                                                                                            python, postgresql, sql, аналитика, базы данных, аналитическое мышление, yandex.datalens
# 16   79834713  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 17   79835994  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 18   79756342  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 19   79317461  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 sql
# 20   76784959  Аналитик данных                                                                                                                                                                                                                                                                                                     python, sql, data analysis, postgresql, machine learning, математическая статистика, r, stata, statistica, spss
# 21   79664162  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 22   79471102  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                             sap bi, продвинутый пользователь пк, bi
# 23   79223944  Аналитик данных                                                                                                                                                                                                                                                                                                                                           ms word, ms excel, многозадачность, отличное знание пк, базовые знания 1с
# 24   78054273  Аналитик данных                                                                                                                                                                                                                                                                                                                                                               opencv, аналитическое мышление, python, deep learning
# 25   79157478  Аналитик данных                                                                                                                                                                                                                                                                                                          python, sql, базы данных, numpy, data analysis, удаленная работа, pandas, google analytics, яндекс.метрика
# 26   78855362  Аналитик данных                                                                                                       python, jupyter notebook, business intelligence systems, data analysis, анализ данных, аналитическое мышление, big data, ml, ms excel, etl, a/b тесты, mathematical statistics, sql, power query, работа в команде, data science, математическая статистика, регрессионный анализ, статистический анализ, git
# 27   78443447  Аналитик данных                                                                                                                                                                                                                                                                                                                           ms sql, postgresql, vba, clickhouse, с#, python, ms sql server, базы данных, data science
# 28   77621491  Аналитик данных                                                                                                                                                                                                                                                                                                                     субд, arenadata, oracle, ms sql, sql, анализ данных, c++, bitbucket, python, team city, airflow
# 29   77370814  Аналитик данных                                                                                                                                                                                                                                                                                                                                              power bi, power pivot, ms excel, факторный анализ, power query, python
# 30   79891448  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 31   78809962  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                 ms power bi, excel, английский язык
# 32   78746121  Аналитик данных                                                                                                                                                                                                                                                                                         ценообразование, аналитическое мышление, abc-анализ, аналитика, контроль и анализ ценообразования, excel, розничные продажи
# 33   79891447  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 34   79232530  Аналитик данных                                                                                                                                                                                                                                                                                                                                                ms powerpoint, работа в команде, анализ данных, деловое общение, vba
# 35   79661029  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 36   67224916  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                   sql, анализ данных, data analysis
# 37   79117416  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 38   77800028  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                               python, sql, bpmn, uml, oracle pl/sql
# 39   78890801  Аналитик данных                                                                                                                                                                                                                                                                                                                                                  аналитика данных, elastic search, lucene, grafana, logstash, kafka
# 40   78723382  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 41   79891449  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 42   79890199  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 43   79919594  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                             python, pandas, sql, ml
# 44   78964240  Аналитик данных                                                power bi, аналитические исследования, анализ бизнес показателей, анализ данных, 1с: комплексная автоматизация, 1c erp, 1с: управление предприятием, автоматизация процессов, data analysis, 1с: управление торговлей, modus bi, ms excel, ms office, аналитическое мышление, расчет премий и бонусов, бизнес-моделирование, бизнес-анализ, описание бизнес-процессов
# 45   79500682  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                       аналитическое мышление, sql, python, power bi
# 46   79795192  Аналитик данных                                                                                                                                                                                                                               английский язык, ms access, ms powerpoint, работа с базами данных, google docs, работа с большим объемом информации, базы данных, умение работать в коллективе, microsoft access, sql
# 47   79105527  Аналитик данных                                                                                                                                                                                                                                                       аналитическое мышление, анализ данных, деловое общение, ориентация на результат, ms powerpoint, работа с большим объемом информации, умение слушать и слышать
# 48   79774234  Аналитик данных                                                                                                                                                                                                                                                                                                                                                 английский язык, etl, аналитика, визуализация данных, ms sql, qilik
# 49   79903357  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                         субд, работа с базами данных, sql, power bi
# 50   79893566  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                  sql, python, spark
# 51   78721862  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                  qgis, arcgis, гис, sql, postgresql
# 52   79841648  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 53   79839563  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 54   79082205  Аналитик данных                                                                                                                                                                                                                                                                        умение работать с программами word, excel, power point, аналитическое мышление, формирование отчетности, работа с большим объемом информации
# 55   79923881  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 56   76052926  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 57   79790691  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 58   78663344  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                    python, sql, визуализация данных
# 59   79779869  Аналитик данных                                                                                                                                                                                                                                                                                                                                    hadoop, ms sql, удаленная работа, dwh, big data, ms excel, python, анализ данных
# 60   79789476  Аналитик данных                                                                                                                                                                                                                                                                                                                         business intelligence systems, ms sql, postgresql, python, greenplum, timescaledb, superset
# 61   79127460  Аналитик данных                                                                                                                                                                                                                                                                                            экономический анализ, аналитика продаж, бюджетирование, ценообразование, аналитика, roistat, экономическое моделирование
# 62   79838615  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 63   79864793  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 64   78939135  Аналитик данных                                                                                                                                                                                                c++, ms sql server, python, sql, анализ данных, data mining, power bi, математическая статистика, математическое моделирование, data analysis, java, базы данных, работа с базами данных, аналитические исследования
# 65   79303970  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 66   79889558  Аналитик данных                                                                                                                                                                                                                                                                                                                                         data catalog, dmbok dama, business glossary, data governance, анализ данных
# 67   77541047  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                      sql, olap, power bi, аналитика
# 68   77502305  Аналитик данных                                                                                                                                                                                                                                                                                                                                                     sql, tableau, bi, работа с большим объемом информации, ms excel
# 69   78126292  Аналитик данных                                                                                                                                                                                                                                                                                                              работа с большим объемом информации, работа с базами данных, ms powerpoint, анализ данных, базы данных
# 70   79838174  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 71   79479719  Аналитик данных                                                                                                                                                                                                                                                                                                                           python, sql, статистический анализ, bpmn, uml, etl, powerbi, r, bigdata, machine learning
# 72   79263061  Аналитик данных                                                                                                                                                                                                                                                                                                                                          vba, ms sql, ms power bi, sql, ms excel, анализ данных, ведение отчетности
# 73   76240797  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 74   79886152  Аналитик данных                                                                                                                                                                                                                                                 power bi, oracle bi, ms power bi, работа с большим объемом информации, аналитические способности, работа с базами данных, аналитические исследования, анализ данных
# 75   79869509  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                        fine bi, sql
# 76   79706584  Аналитик данных                                                                                                                                                                                                                                                                                                                        ms sql, sql, sap erp, знание excel, excel, vba, access, transact-sql, pl-sql, sap, ms office
# 77   79774050  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 78   78127543  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 79   78309106  Аналитик данных                                                                                                                                                                                                                                                                                                                            ms sql, субд, postgresql, oracle, teradata, qliksense, tableau, superset, python, hadoop
# 80   79885403  Аналитик данных                                                                                                                                                                                                                                                                                                      sql, python, postgresql, pandas, математическое моделирование, анализ временных рядов, теория вероятностей, ml
# 81   78772632  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 82   78964975  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                     clickhouse, sql
# 83   79499449  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 84   79724096  Аналитик данных                                                                                                                                                                                                                                                                                                                                          python, sql, tableau, работа с большим объемом информации, прогнозирование
# 85   78637745  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                            sql, scrum, анализ данных, ms powerpoint
# 86   79672685  Аналитик данных                                                                                                                                                                                             ad hoc analysis, отчетность, ms powerpoint, bi, ms excel, tableau, анализ бизнес показателей, анализ данных, навыки презентации, аналитическое мышление, умение принимать решения, деловая коммуникация, генерация идей
# 87   79106964  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 88   79814897  Аналитик данных                                                                                                                                                                                                                                                                                                         abc-анализ, анализ рынка, аналитическое мышление, анализ продаж, умение работать в коллективе, abc analysis
# 89   70368551  Аналитик данных                                                                                                                                                                                                                                                                                                                                                               python, sql, математическая статистика, анализ данных
# 90   77848600  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 sql
# 91   77436241  Аналитик данных                                                                                                                                                                                                                                                                                                                                                          ms sql, бизнес-анализ, управленческая отчетность, ms excel
# 92   79270707  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 sql
# 93   79225814  Аналитик данных                                                                                                                                                                                                                                                                                                                              анализ данных, аналитические исследования, работа с большим объемом информации, ms sql
# 94   78632808  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                   ms sql, python, анализ данных, clickhouse, hadoop
# 95   79837096  Аналитик данных  ms sql, sql, продвинутый уровень sql(аналитические функции, подзапросы, хранимые процедуры, оптимизация запросов), продвинутый уровень ms office (макросы), субд, анализ данных, системное мышление, знание основ финансового анализа, ms excel, teradata, python, hadoop, знание классических банковских продуктов, понимание инвестиционных продуктов, знание математической статистики и методов анализа данных
# 96   79708385  Аналитик данных                                                                                                                                                                                                                                                                                                       веб-аналитика, визуализация данных, статистический анализ, аналитические исследования, a/b тесты, sql, python
# 97   79012951  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 98   78687196  Аналитик данных                                                                                                                                                                                                                                                                                      sql, business intelligence systems, python, a/b тесты, powerbi, умение работать в условиях многозадачности, коммуникабельность
# 99   78632172  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 100  78759476  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                         sql, python
# 101  79741946  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 102  78711842  Аналитик данных                                                                                                                                                                                                                                                         grafana, power bi, дашборды, spark, python, sql, аналитическое мышление, проведение тестирований, a/b тесты, теория вероятностей, математическая статистика
# 103  77450912  Аналитик данных                                                                                                                                                                                                                                                                                                                             sql, python, математическая статистика, data analysis, математический анализ, алгоритмы
# 104  79012615  Аналитик данных                                                                                                                                                                                                                                              английский язык, аналитический склад ума, анализ данных, работа с большим объемом информации, математическая статистика, подготовка презентаций, математический анализ
# 105  78561259  Аналитик данных                                                                                                                                                                                                                                                                                                                                                               opencv, python, deep learning, аналитическое мышление
# 106  79428096  Аналитик данных                                                                                                                                                                                              ibm spss, статистический анализ, маркетинговые исследования, ms excel, математическая статистика, статистика, социологические исследования, анализ данных, работа с базами данных, работа с большим объемом информации
# 107  79708402  Аналитик данных                                                                                                                                                                                                                                                                             анализ данных, аналитическое мышление, ms sql, google analytics, power bi, python, статистический анализ, sap business objects, tableau
# 108  78671690  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 sql
# ...
# 466  79927560  Аналитик данных                                                                                                                                                                                                                                                                                               телекоммуникации, конкурентная аналитика, работа в условиях многозадачности, маркетинговые исследования, анализ рынка
# 467  78923014  Аналитик данных                                                           постановка задач разработчикам, внутренние коммуникации, бизнес-анализ, оптимизация бизнес-процессов, бизнес-моделирование, системное мышление, работа в режиме многозадачности, разработка инструкций, техническое задание, внутренний финансовый аудит, составление презентаций, ms crm, написание инструкций, аналитическое мышление, sql, 1c: финансы
# 468  78670298  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 469  79163403  Аналитик данных                                                                                                                                                                                                                                                                                                                     маркетинговые исследования, анализ рынка, прогнозирование, swot анализ, ms powerpoint, power bi
# 470  77863306  Аналитик данных                                                                                                                                                                                                                                            power bi, аналитическое мышление, работа с большим объемом информации, анализ финансовых показателей, подготовка отчетов, аналитика, exсel, пользователь пк, sql, python
# 471  78091528  Аналитик данных                                                                                                                                                                                                                                                                                                         деловая переписка, 1с: предприятие 8, аналитическое мышление, ms excel, анализ данных, управление проектами
# 472  79744213  Аналитик данных                                                                                                                                                                                                                                     sql, аналитическое мышление, анализ данных, ms powerpoint, работа с большим объемом информации, excel, работа с базами данных, аналитика, многозадачность, умение анализировать
# 473  79159552  Аналитик данных                                                                                                                                                                                                                                                                                                                                            маркетинговый анализ, анализ данных, анализ бизнес показателей, ms excel
# 474  79159553  Аналитик данных                                                                                                                                                                                                                                                                                                                                            маркетинговый анализ, анализ данных, анализ бизнес показателей, ms excel
# 475  79664163  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 476  79515526  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                    экономический анализ, sql, excel
# 477  79293278  Аналитик данных                                                                                                                                                                                               sql, работа с системами аналитики, базы данных, google docs, data studio, datalens, google sheets, ms excel, bi-инструменты, clickhouse, python, работа в команде, аналитические исследования, конкурентная аналитика
# 478  79117409  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 479  76050244  Аналитик данных                                                                                                                                                                                                                                                                  сводные таблицы, впр, работа с большим объемом информации, работа с базами данных, анализ данных, аналитическое мышление, excel, 1с: предприятие 8
# 480  78028018  Аналитик данных                                                                                                                                                                                                                                                                                                                                                              sql, uml, базы данных, субд, коммуникативная стратегия
# 481  79173257  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                               sql, etl, informatica
# 482  78108087  Аналитик данных                                                                                                                                                                                                                                                                                                                             структурированность, базы данных, sql запросы, аналитическая работа, vba, ms excel, впр
# 483  77621559  Аналитик данных                                                                                                                                                                                                                                                                                                                     субд, arenadata, oracle, ms sql, sql, анализ данных, c++, bitbucket, python, team city, airflow
# 484  79709713  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 485  76756079  Аналитик данных                                                                                                                                                                                                                                                                           работа с большим объемом информации, анализ данных, аналитическое мышление, excel, ведение базы данных, нси, оптимизация бизнес-процессов
# 486  79933710  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 487  79750621  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 488  78054274  Аналитик данных                                                                                                                                                                                                                                                                                                                                                               opencv, аналитическое мышление, python, deep learning
# 489  79117406  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 490  79295010  Аналитик данных                                                                                                                                                                                                                                                                                                                                               sql, sap bw, power bi, postgresql, oracle, ms sharepoint, power query
# 491  79471103  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                             sap bi, продвинутый пользователь пк, bi
# 492  74334953  Аналитик данных                                                                                                                                                                                                                                                               работа в команде, работа с базами данных, работа с большим объемом информации, грамотная речь, деловое общение, excel, уверенный пользователь пк, нси
# 493  79471101  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                             sap bi, продвинутый пользователь пк, bi
# 494  78831354  Аналитик данных                                                                                                                                                                                                                                                                                        базы данных, ms excel, ценообразование, работа с большим объемом информации, big data, data analysis, работа с базами данных
# 495  79664160  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 496  79117418  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 497  79643918  Аналитик данных                                                                                                                                                                                                            ответственность, внимательность, системный подход, знание и понимание принципов прогнозирования, умение анализировать и интерпретировать данные, анализ данных, excel, базы данных, power bi, qlik sense
# 498  79750623  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                                                                 NaN
# 499  78935610  Аналитик данных                                                                                                                                                                                                                                                                                                                                                                           etl, sql, teradata, oracle pl/sql, python
# 500  77697328  Аналитик данных                                            python, sql, математическая статистика, математическое моделирование, power bi, data analysis, математический анализ, навыки работы с большим объемом информации, 1c: финансы, профессиональный пользователь пк, аналитические навыки, коммуникабельность, ответственность, работа в условиях многозадачности, ответственность и пунктуальность, высокая ответственность
# 501  78763637  Аналитик данных                                                                                                                                                                                                                                                                                                                                                           sql, аналитическое мышление, математическое моделирование

# %%
ad = pd.read_csv('results/Аналитик данных_vac.csv', sep=';', encoding='utf-8')
ad.drop(['job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency'], 
         axis=1, inplace=True)
ad.head()
# Out:
#          id             spec  \
# 0  76279241  Аналитик данных
# 1  78521948  Аналитик данных
# 2  78345488  Аналитик данных
# 3  79479573  Аналитик данных
# 4  78054272  Аналитик данных
#
#                                               skills
# 0  ms excel, бизнес-анализ, аналитические исследо...
# 1  sql, работа с базами данных, английский язык, ...
# 2  анализ данных, tableau, статистический анализ,...
# 3      power bi, sql, powerbi, базы данных, ms excel
# 4  opencv, аналитическое мышление, python, deep l...

# %%
# напрямую с файлами
ac = pd.read_csv('results/1С-аналитик_vac.csv', sep=';', encoding='utf-8')
ds = pd.read_csv('results/Data Scientist_vac.csv', sep=';', encoding='utf-8')
do = pd.read_csv('results/DataOps-инженер_vac.csv', sep=';', encoding='utf-8')
ab = pd.read_csv('results/Аналитик BI_vac.csv', sep=';', encoding='utf-8')
ad = pd.read_csv('results/Аналитик данных_vac.csv', sep=';', encoding='utf-8')
# dj = pd.read_csv('results/Дата-журналист_vac.csv', sep=';', encoding='utf-8')
de = pd.read_csv('results/Дата-инженер_vac.csv', sep=';', encoding='utf-8')
ma = pd.read_csv('results/Маркетинговый аналитик_vac.csv', sep=';', encoding='utf-8')
pa = pd.read_csv('results/Продуктовый аналитик_vac.csv', sep=';', encoding='utf-8')
sa = pd.read_csv('results/Системный аналитик_vac.csv', sep=';', encoding='utf-8')
fa = pd.read_csv('results/Финансовый аналитик_vac.csv', sep=';', encoding='utf-8')
ba = pd.read_csv('results/Бизнес-аналитик_vac.csv', sep=';', encoding='utf-8')

# %%
# добавление меток широта-долгота
with open('geo_rus.json', encoding='utf-8') as geo:
    cities = json.load(geo)

def lat(row):
    for el in cities:
        if row == el['city']:
            return float(el['lat'])
        
def lon(row):
    for el in cities:
        if row == el['city']:
            return float(el['lon'])

# %%
full = pd.concat([ds, do, ab, ad, dj, de, ma, sa, ac, fa, ba, pa])
# full.to_csv('vacancies.csv', index=False)

full['lat'] = full['city'].apply(lat)
full['lon'] = full['city'].apply(lon)
full = full[['id', 'spec', 'job_title', 'city', 'lat', 'lon', 
         'employer', 'schedule', 'skills', 'experience', 
         'published', 'salary_from', 'salary_to', 'currency']]

# %%
ac_sk = ['1c|1с', 'agile|scrum|kanban', 'управление', 'erp', 'отчет',
         'анализ', 'тз', 'srs', 'моделирование', 'bpmn', 'тестирование',
         'документ']

ds_sk = ['анализ', 'sheets', 'статистика', 'data studio', 'python', 'sql',
         'ml', 'machine learning', 'сбор', 'визуализация', 'исследование',
         'нейронные сети', 'нейросети', 'временные ряды', 'алгоритм',
         'sklearn', 'tensorflow', 'pytorch','cv', 'gan', 'nlp']

de_do_sk = ['sql', 'базы данных', 'etl', 'power bi|powerbi', 'python', 
            'pandas', 'numpy', 'hadoop', 'mapreduce', 'apache', 'kafka', 
            'spark', 'airflow', 'clickhouse', 'yandex cloud', 'docker', 
            'kubernetes', 'ansible', 'gitlab ci', 'mlflow']

ab_sk = ['анализ', 'sheets', 'excel', 'статистика', 'визуализация', 
         'data studio', 'power bi|powerbi', 'pivot', 'datalens', 'tableau',
         'сбор', 'sql', 'ssas']

ad_sk = ['анализ', 'sheets', 'excel', 'статистика', 'визуализация',
         'data studio', 'python', 'jupyter notebook', 'numpy', 
         'pandas', 'сбор', 'sql', 'ml', 'machine learning', 'hadoop']

dj_sk = ['анализ', 'сбор', 'очистка', 'визуализация', 'построение карт', 'сторителлинг',
         'python', 'pandas', 'статистика', 'tableau']

ma_sk = ['анализ', 'sheets', 'статистика', 'визуализация', 'google looker studio',
         'метрики', 'юнит-экономика', 'поиск точек роста', 'RFM-анализ', 
         'когортный анализ', 'веб-аналитика', 'яндекс метрика', 'google analitics',
         'ab', 'sql', 'power bi|powerbi', 'python', 'numpy', 'pandas', 'api']

pa_sk = ['анализ', 'юнит-экономика', 'ab', 'sql', 'tableau', 'power bi|powerbi', 
         'python', 'numpy', 'pandas', 'исследов']

sa_sk = ['разработка по', 'agile', 'scrum', 'моделирование бизнес-процессов',
         'нотации', 'проектирование', 'сбор', 'описание', 'визуализация',
         'прототипирование', 'figma', 'sql', 'rest api', 'soap', 'open api',
         'проектная документация', 'cjm', 'тз', 'спецификация', 'SRS', 'bcm']

fa_sk = ['1с', 'бухгалтер', 'финансовая', 'анализ', 'управление', 'статистика', 
         'план-фактный анализ', 'планирование', 'моделирование', 'презентац',
         'powerpoint', 'excel', 'визуализация']

ba_sk = ['моделирование', 'анализ', 'оптимизация', 'отчетност', 'сбор',
         'tableau', 'bi', 'исследовани', 'agile|scrum|kanban', 'тз', 'документ']

# %% [markdown]
# #### 1 / 12 Аналитик данных, подготовка к конкату

# %%
ad.drop(['job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency'], 
         axis=1, inplace=True)
ad.skills.replace(NaN, '-', inplace=True)

def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

lens = ad.skills.str.split(',').map(len)

ad = pd.DataFrame({'id': np.repeat(ad['id'], lens),
                    'spec': np.repeat(ad['spec'], lens),
                    'skills': chainer(ad['skills'])})
# ad.head()
lens

# %%
ad = ad.loc[ad.skills.str.contains('|'.join(ad_sk))]
ad.skills = ad.skills.str.strip()

ad.skills.loc[(ad.skills.str.contains('sql'))] = 'sql'
ad.skills.loc[(ad.skills.str.contains('excel'))] = 'excel'
ad.skills.loc[(ad.skills.str.contains('machine learning'))] = 'ml'
ad.skills.loc[(ad.skills.str.contains('анализ'))] = 'анализ (данных, финансовый, т.д.)'

# %% [markdown]
# #### 2 / 12 Data Scientist, подготовка к конкату

# %%
ds.drop(['job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency'], 
         axis=1, inplace=True)
ds.skills.replace(NaN, '-', inplace=True)

def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

lens = ds.skills.str.split(',').map(len)

ds = pd.DataFrame({'id': np.repeat(ds['id'], lens),
                    'spec': np.repeat(ds['spec'], lens),
                    'skills': chainer(ds['skills'])})

# %%
ds = ds.loc[ds.skills.str.contains('|'.join(ds_sk))]
ds.skills = ds.skills.str.strip()

ds.skills.loc[(ds.skills.str.contains('sql'))] = 'sql'
ds.skills.loc[(ds.skills.str.contains('excel'))] = 'excel'
ds.skills.loc[(ds.skills.str.contains('machine learning'))] = 'ml'
ds.skills.loc[(ds.skills.str.contains('ml'))] = 'ml'
ds.skills.loc[(ds.skills.str.contains('анализ'))] = 'анализ (данных, финансовый, т.д.)'

# %% [markdown]
# #### 3 / 12 Аналитик BI, подготовка к конкату

# %%
ab.drop(['job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency'], 
         axis=1, inplace=True)
ab.skills.replace(NaN, '-', inplace=True)

def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

lens = ab.skills.str.split(',').map(len)

ab = pd.DataFrame({'id': np.repeat(ab['id'], lens),
                    'spec': np.repeat(ab['spec'], lens),
                    'skills': chainer(ab['skills'])})

# %%
ab = ab.loc[ab.skills.str.contains('|'.join(ab_sk))]
ab.skills = ab.skills.str.strip()

ab.skills.loc[(ab.skills.str.contains('sql'))] = 'sql'
ab.skills.loc[(ab.skills.str.contains('excel'))] = 'excel'
ab.skills.loc[(ab.skills.str.contains('bi'))] = 'power bi'
ab.skills.loc[(ab.skills.str.contains('pivot'))] = 'pivot'
ab.skills.loc[(ab.skills.str.contains('анализ'))] = 'анализ (данных, финансовый, т.д.)'

# %% [markdown]
# #### 4 / 12 Системный аналитик, подготовка к конкату

# %%
sa.drop(['job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency'], 
         axis=1, inplace=True)
sa.skills.replace(NaN, '-', inplace=True)

def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

lens = sa.skills.str.split(',').map(len)

sa = pd.DataFrame({'id': np.repeat(sa['id'], lens),
                    'spec': np.repeat(sa['spec'], lens),
                    'skills': chainer(sa['skills'])})

# %%
sa = sa.loc[sa.skills.str.contains('|'.join(sa_sk))]
sa.skills = sa.skills.str.strip()

sa.skills.loc[(sa.skills.str.contains('sql'))] = 'sql'
sa.skills.loc[(sa.skills.str.contains('agile'))] = 'agile'
sa.skills.loc[(sa.skills.str.contains('тз'))] = 'написание тз'
sa.skills.loc[(sa.skills.str.contains('soap'))] = 'soap'
sa.skills.loc[(sa.skills.str.contains('моделирование | проектирование'))] = 'проектирование (интерфейсов, api, т.д.)'
sa.skills.loc[(sa.skills.str.contains('сбор требований'))] = 'сбор требований'

# %% [markdown]
# #### 5 / 12 Маркетинговый аналитик, подготовка к конкату

# %%
ma.drop(['job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency'], 
         axis=1, inplace=True)
ma.skills.replace(NaN, '-', inplace=True)

def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

lens = ma.skills.str.split(',').map(len)

ma = pd.DataFrame({'id': np.repeat(ma['id'], lens),
                    'spec': np.repeat(ma['spec'], lens),
                    'skills': chainer(ma['skills'])})

# %%
ma = ma.loc[ma.skills.str.contains('|'.join(ma_sk))]
ma.skills = ma.skills.str.strip()

ma.skills.loc[(ma.skills.str.contains('анализ'))] = 'анализ (данных, финансовый, т.д.)'
ma.skills.loc[(ma.skills.str.contains('sql'))] = 'sql'
ma.skills.loc[(ma.skills.str.contains('статистика'))] = 'статистика'

# %% [markdown]
# #### 6 / 12 Дата-журналист, подготовка к конкату

# %%
dj.drop(['job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency'], 
         axis=1, inplace=True)
dj.skills.replace(NaN, '-', inplace=True)

def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

lens = dj.skills.str.split(',').map(len)

dj = pd.DataFrame({'id': np.repeat(dj['id'], lens),
                    'spec': np.repeat(dj['spec'], lens),
                    'skills': chainer(dj['skills'])})

# %%
dj = dj.loc[dj.skills.str.contains('|'.join(dj_sk))]
dj.skills = dj.skills.str.strip()

dj.skills.loc[(dj.skills.str.contains('анализ'))] = 'анализ (данных, финансовый, т.д.)'
dj.skills.loc[(dj.skills.str.contains('сбор'))] = 'сбор данных'
dj.skills.loc[(dj.skills.str.contains('визуализация'))] = 'визуализация данных'
dj.skills.loc[(dj.skills.str.contains('storytelling'))] = 'сторителлинг'
dj.skills.loc[(dj.skills.str.contains('story telling'))] = 'сторителлинг'

# %% [markdown]
# #### 7-8 / 12 Дата-инженер | DataOps-инженер, подготовка к конкату

# %%
#DataOps
do.drop(['job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency'], 
         axis=1, inplace=True)
do.skills.replace(NaN, '-', inplace=True)

def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

lens = do.skills.str.split(',').map(len)

do = pd.DataFrame({'id': np.repeat(do['id'], lens),
                    'spec': np.repeat(do['spec'], lens),
                    'skills': chainer(do['skills'])})

# %%
do = do.loc[do.skills.str.contains('|'.join(de_do_sk))]
do.skills = do.skills.str.strip()

do.skills.unique()

# do.skills.loc[(do.skills.str.contains('...'))] = '...'
# do.skills.loc[(do.skills.str.contains('...'))] = '...'

# %%
# дата-инженер
de.drop(['job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency'], 
         axis=1, inplace=True)
de.skills.replace(NaN, '-', inplace=True)

def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

lens = de.skills.str.split(',').map(len)

de = pd.DataFrame({'id': np.repeat(de['id'], lens),
                    'spec': np.repeat(de['spec'], lens),
                    'skills': chainer(de['skills'])})

# %%
de = de.loc[de.skills.str.contains('|'.join(de_do_sk))]
de.skills = de.skills.str.strip()

de.skills.loc[(de.skills.str.contains('sql'))] = 'sql'
de.skills.loc[(de.skills.str.contains('bi'))] = 'power bi'
de.skills.loc[(de.skills.str.contains('airflow'))] = 'airflow'
de.skills.loc[(de.skills.str.contains('nifi|ni-fi'))] = 'nifi'

# %% [markdown]
# #### 9 / 12 Финансовый аналитик, подготовка к конкату

# %%
fa.drop(['job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency'], 
         axis=1, inplace=True)
fa.skills.replace(NaN, '-', inplace=True)

def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

lens = fa.skills.str.split(',').map(len)

fa = pd.DataFrame({'id': np.repeat(fa['id'], lens),
                    'spec': np.repeat(fa['spec'], lens),
                    'skills': chainer(fa['skills'])})

# %%
fa = fa.loc[fa.skills.str.contains('|'.join(fa_sk))]
fa.skills = fa.skills.str.strip()

fa.skills.loc[(fa.skills.str.contains('1с|1c'))] = '1с (предприятие, бухгалтерия)'
fa.skills.loc[(fa.skills.str.contains('excel'))] = 'excel'
fa.skills.loc[(fa.skills.str.contains('powerpoint|презент'))] = 'powerpoint'
fa.skills.loc[(fa.skills.str.contains('анали'))] = 'анализ (данных, финансовый, т.д.)'
fa.skills.loc[(fa.skills.str.contains('управление'))] = 'управление (рисками, затратами, т.д.)'
fa.skills.loc[(fa.skills.str.contains('планирование'))] = 'планирование (финансовое, инвестиционное, т.д.)'
fa.skills.loc[(fa.skills.str.contains('моделирование'))] = 'моделирование (финансовое, экономическое, т.д.)'
fa.skills.loc[(fa.skills.str.contains('бухгал'))] = 'бухучёт'
fa.skills.loc[(fa.skills.str.contains('статистика'))] = 'статистика'
fa.skills.loc[(fa.skills.str.contains('визуализация'))] = 'визуализация'

# %% [markdown]
# #### 10 / 12 1С-аналитик, подготовка к конкату

# %%
ac.drop(['job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency'], 
         axis=1, inplace=True)
ac.skills.replace(NaN, '-', inplace=True)

def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

lens = ac.skills.str.split(',').map(len)

ac = pd.DataFrame({'id': np.repeat(ac['id'], lens),
                    'spec': np.repeat(ac['spec'], lens),
                    'skills': chainer(ac['skills'])})

# %%
ac = ac.loc[ac.skills.str.contains('|'.join(ac_sk))]
ac.skills = ac.skills.str.strip()

ac.skills.loc[(ac.skills.str.contains('1с|1c'))] = '1с (предприятие, бухгалтерия)'
ac.skills.loc[(ac.skills.str.contains('отчетность'))] = 'отчетность (налоговая, бухгалтерская)'
ac.skills.loc[(ac.skills.str.contains('powerpoint'))] = 'powerpoint'
ac.skills.loc[(ac.skills.str.contains('документ'))] = 'проектная документация'

# %% [markdown]
# #### 11 / 12 Продуктовый аналитик, подготовка к конкату

# %%
pa.drop(['job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency'], 
         axis=1, inplace=True)
pa.skills.replace(NaN, '-', inplace=True)

def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

lens = pa.skills.str.split(',').map(len)

pa = pd.DataFrame({'id': np.repeat(pa['id'], lens),
                    'spec': np.repeat(pa['spec'], lens),
                    'skills': chainer(pa['skills'])})

# %%
pa = pa.loc[pa.skills.str.contains('|'.join(pa_sk))]
pa.skills = pa.skills.str.strip()

pa.skills.loc[(pa.skills.str.contains('sql'))] = 'sql'
pa.skills.loc[(pa.skills.str.contains('анализ|analys'))] = 'анализ (данных, финансовый, т.д.)'
pa.skills.loc[(pa.skills.str.contains('bi'))] = 'power bi'
pa.skills.loc[(pa.skills.str.contains('исследов'))] = 'проведение исследований'

# %% [markdown]
# #### 12 / 12 Бизнес-аналитик, подготовка к конкату

# %%
ba.drop(['job_title', 'city', 'employer', 'schedule', 'experience',
         'published', 'salary_from', 'salary_to', 'currency'], 
         axis=1, inplace=True)
ba.skills.replace(NaN, '-', inplace=True)

def chainer(s):
    return list(chain.from_iterable(s.str.split(',')))

lens = ba.skills.str.split(',').map(len)

ba = pd.DataFrame({'id': np.repeat(ba['id'], lens),
                    'spec': np.repeat(ba['spec'], lens),
                    'skills': chainer(ba['skills'])})

# %%
ba = ba.loc[ba.skills.str.contains('|'.join(ba_sk))]
ba.skills = ba.skills.str.strip()

ba.skills.loc[(ba.skills.str.contains('анализ'))] = 'анализ (данных, финансовый, т.д.)'
ba.skills.loc[(ba.skills.str.contains('моделирование'))] = 'моделирование (финансовое, экономическое, т.д.)'
ba.skills.loc[(ba.skills.str.contains('отчет'))] = 'отчетность (налоговая, бухгалтерская)'
ba.skills.loc[(ba.skills.str.contains('bi'))] = 'bi-системы'
ba.skills.loc[(ba.skills.str.contains('документ'))] = 'проектная документация'
ba.skills.loc[(ba.skills.str.contains('оптимизация'))] = 'оптимизация процессов'
ba.skills.loc[(ba.skills.str.contains('исследов'))] = 'проведение исследований'
ba.skills.loc[(ba.skills.str.contains('тз'))] = 'составление тз'
ba.skills.loc[(ba.skills.str.contains('сбор'))] = 'сбор требований'
ba.skills.loc[(ba.skills.str.contains('agile'))] = 'agile'

# %% [markdown]
# #### Конкат + топ-15 навыков + сводная

# %%
df = pd.concat([ds, do, ab, ad, dj, de, ma, sa, ac, fa, ba, pa])
df.skills.replace(NaN, '-', inplace=True)
df

# %%
top_15 = df.skills.value_counts().to_frame().reset_index().head(15)
list_top = list(top_15.skills)
list_top

# %%
df = df[df.skills.isin(list_top)]

# %%
df = pd.pivot_table(
    df,
    index='skills',
    columns='spec',
    values='id',
    aggfunc='count'
).reset_index()

# %%
df

# %%
df.to_excel('key_skills.xlsx', index=False)

# %% [markdown]
# # Карта РФ

# %%
df = full.groupby('city')['id'].count()
df

# %%
import plotly.express as px

fig = px.scatter_mapbox(full, lat="lat", lon="lon",
                        size='id', size_max=5,)
fig.update_layout(
        mapbox=dict(
            accesstoken='pk.eyJ1IjoiZHVtYmZpc2giLCJhIjoiY2xobTc3YXVrMTltZzNocXAwNzQxcG9tdSJ9.HyrRTRTCyDWgZdaFWadHxQ',
            style='mapbox://styles/dumbfish/clhm8mm6c01n701pr051pebv8'
        )
    )
